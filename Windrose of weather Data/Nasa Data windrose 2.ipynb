# %%
import pandas as pd
Data=pd.read_excel("C:\\Users\\Zubair Ahmed\\Desktop\\LST.xlsx",header=0)

# %%
Data.head()
# Out:
#    YEAR  MO  DY  HR  WS10M  WD10M  WS50M  WD50M
# 0  2021   1   1   4   3.95  16.43   5.35  15.60
# 1  2021   1   1   5   3.96  18.40   5.32  17.96
# 2  2021   1   1   6   3.85  20.94   5.18  20.87
# 3  2021   1   1   7   3.65  22.67   4.62  22.70
# 4  2021   1   1   8   3.35  22.74   3.55  22.95

# %%
from windrose import WindroseAxes
ws=Data.iloc[:,4]
wd=Data.iloc[:,5]
ax = WindroseAxes.from_ax()
ax.bar(wd, ws, opening=0.8, edgecolor='white',normed=True,bins=[0,0.5,2.1,3.6,5.7,8.8,11.1])
ax.set_legend()

# %%
import numpy as np
np.percentile(ws,25)
# Out:
# 2.87

# %%
ws.describe()
# Out:
# count    8756.000000
# mean        4.426279
# std         2.143834
# min         0.110000
# 25%         2.870000
# 50%         4.100000
# 75%         5.720000
# max        12.020000
# Name: WS10M, dtype: float64
